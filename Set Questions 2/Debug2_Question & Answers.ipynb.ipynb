# %% [markdown]
# ## **1.Module Not Found Error**

# %%
import numpy as np

# Missing import for TensorFlow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layer import Dense

# Generate dummy data
X_train = np.random.rand(100, 10)
Y_train = np.random.randint(0, 2, size=(100,))

# Define the model
model = Sequential([
    Dense(32, activation='relu', input_shape=(10,)),
    Dense(1, activation='sigmoid')
])

# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train model
model.fit(X_train, y_train, epochs=5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2122/3819754584.py in <cell line: 0>()
#       3 # Missing import for TensorFlow
#       4 from tensorflow.keras.models import Sequential
# ----> 5 from tensorflow.keras.layer import Dense
#       6
#       7 # Generate dummy data
#
# ModuleNotFoundError: No module named 'tensorflow.keras.layer'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Incorrect Code
# from tensorflow.keras.layer import Dense
#
#
# Correct Code
# from tensorflow.keras.layers import Dense
#
# (layers - plural)
#
# ===========
# Incorrect Code
#
# model.fit(X_train, y_train, epochs=5)
#
# Correct Code
# model.fit(X_train, Y_train, epochs=5)
#
# y = Y (capital Y)
# ========
#
# ## **1.Solution**

# %%
import numpy as np

# Missing import for TensorFlow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Generate dummy data
X_train = np.random.rand(100, 10)
Y_train = np.random.randint(0, 2, size=(100,))

# Define the model
model = Sequential([
    Dense(32, activation='relu', input_shape=(10,)),
    Dense(1, activation='sigmoid')
])

# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train model
model.fit(X_train, Y_train, epochs=5)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5500 - loss: 0.7189
# Epoch 2/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5500 - loss: 0.7128
# Epoch 3/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5400 - loss: 0.7069
# Epoch 4/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5400 - loss: 0.7030
# Epoch 5/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5700 - loss: 0.6996

# %% [markdown]
# TensorFlow Binary Classification Code
#
# | Code                                              | Purpose             | Explanation                                                 |
# | ------------------------------------------------- | ------------------- | ----------------------------------------------------------- |
# | `import numpy as np`                              | Import NumPy        | Used for numerical operations and creating dummy data.      |
# | `from tensorflow.keras.models import Sequential`  | Import Sequential   | Used to create a neural network layer by layer.             |
# | `from tensorflow.keras.layers import Dense`       | Import Dense Layer  | Used to add fully connected neural network layers.          |
# | `X_train = np.random.rand(100, 10)`               | Generate Input Data | Creates 100 samples with 10 features each.                  |
# | `Y_train = np.random.randint(0, 2, size=(100,))`  | Generate Labels     | Creates binary labels (0 or 1) for 100 samples.             |
# | `model = Sequential([...])`                       | Create Model        | Defines the neural network architecture.                    |
# | `Dense(32, activation='relu', input_shape=(10,))` | Hidden Layer        | 32 neurons with ReLU activation, accepts 10 input features. |
# | `Dense(1, activation='sigmoid')`                  | Output Layer        | Produces output between 0 and 1 for binary classification.  |
# | `model.compile(...)`                              | Compile Model       | Configures optimizer, loss function, and evaluation metric. |
# | `optimizer='adam'`                                | Optimizer           | Updates model weights efficiently.                          |
# | `loss='binary_crossentropy'`                      | Loss Function       | Measures error for binary classification problems.          |
# | `metrics=['accuracy']`                            | Evaluation Metric   | Tracks prediction accuracy during training.                 |
# | `model.fit(X_train, Y_train, epochs=5)`           | Train Model         | Trains the model for 5 complete passes through the dataset. |

# %% [markdown]
# ## **2.Mismatched Input Shape in CNN**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense

# Generate dummy image data
X_train = np.random.rand(100, 32, 32)  # Error: Missing the channel dimension
y_train = np.random.randint(0, 10, size=(100,))

# Define CNN Model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)),
    Flatten(),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2122/4050512715.py in <cell line: 0>()
#      17 model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#      18
# ---> 19 model.fit(X_train, y_train, epochs=5)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# ...

# %% [markdown]
# | Item               | Before Error Code                       | Correct Code                               | Reason                                    |
# | ------------------ | --------------------------------------- | ------------------------------------------ | ----------------------------------------- |
# | Training Data      | `X_train = np.random.rand(100, 32, 32)` | `X_train = np.random.rand(100, 32, 32, 3)` | CNN expects images with 3 channels (RGB). |
# | Input Shape        | `(100, 32, 32)`                         | `(100, 32, 32, 3)`                         | Channel dimension was missing.            |
# | Model Input        | `input_shape=(32,32,3)`                 | `input_shape=(32,32,3)`                    | No change required.                       |
# | Data Compatibility | ❌ Not Compatible                        | ✅ Compatible                               | Data shape matches model input shape.     |
# | Result             | ValueError                              | Successful Training                        | Shape mismatch fixed.                     |

# %% [markdown]
# ### **## 2.Solution**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense

# Generate dummy image data
X_train = np.random.rand(100, 32, 32,3)  # Error: Missing the channel dimension
y_train = np.random.randint(0, 10, size=(100,))

# Define CNN Model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)),
    Flatten(),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.fit(X_train, Y_train, epochs=5)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4100 - loss: 1.2679
# Epoch 2/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5200 - loss: 0.6860
# Epoch 3/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5400 - loss: 0.6069
# Epoch 4/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9000 - loss: 0.4168
# Epoch 5/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8600 - loss: 0.3645

# %% [markdown]
# ## **3.Undefined Variable Error**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import AveragePooling2D, Flatten, Dense, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model

# Load pre-trained MobileNetV2 model
baseModel = MobileNetV2(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))

# Add custom layers
headModel = baseModel.output
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dense(1, activation="sigmoid")(headModel)
model = Model(inputs=baseModel.input, outputs=headModel)
# Define missing variables
opt = tf.keras.optimizers.Adam(learning_rate=INIT_LR)
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=INIT_LR,
    decay_steps=1000,  # Adjust this based on dataset size
    decay_rate=0.96,  # Reduce LR by 4% every 1000 steps
    staircase=True
)

# Compile model
opt = Adam(learning_rate=INIT_LR)  # Error: Undefined variables
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])
print("Model compiled successfully")
# Out:
# /tmp/ipykernel_2122/3183389490.py:9: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   baseModel = MobileNetV2(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2122/3183389490.py in <cell line: 0>()
#      16 model = Model(inputs=baseModel.input, outputs=headModel)
#      17 # Define missing variables
# ---> 18 opt = tf.keras.optimizers.Adam(learning_rate=INIT_LR)
#      19 lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
#      20     initial_learning_rate=INIT_LR,
#
# NameError: name 'INIT_LR' is not defined

# %% [markdown]
# INIT_LR = 0.001 Explanation (missing in the code)
#
# ----------
#
# | Item      | Explanation                                                     |
# | --------- | --------------------------------------------------------------- |
# | `INIT_LR` | Initial Learning Rate                                           |
# | `0.001`   | Value of the learning rate                                      |
# | Purpose   | Controls how much the model weights are updated during training |
# | Used By   | Optimizer (Adam, SGD, RMSprop, etc.)                            |
#
#
# =========
#
# ##**3. Solution**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import AveragePooling2D, Flatten, Dense, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model

# Define Learning Rate
INIT_LR = 0.001


# Load pre-trained MobileNetV2 model
baseModel = MobileNetV2(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))

# Add custom layers
headModel = baseModel.output
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dense(1, activation="sigmoid")(headModel)
model = Model(inputs=baseModel.input, outputs=headModel)
# Define missing variables
opt = tf.keras.optimizers.Adam(learning_rate=INIT_LR)
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=INIT_LR,
    decay_steps=1000,  # Adjust this based on dataset size
    decay_rate=0.96,  # Reduce LR by 4% every 1000 steps
    staircase=True
)

# Compile model
opt = Adam(learning_rate=INIT_LR)  # Error: Undefined variables
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])
print("Model compiled successfully")
# Out:
# /tmp/ipykernel_2122/1222400710.py:13: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   baseModel = MobileNetV2(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))
# Model compiled successfully

# %% [markdown]
# ## **4.FileNotFoundError**

# %%
from PIL import Image

# ❌ ERROR: Wrong file name or missing file
image_path = "flow.jpg"
img = Image.open(image_path)  # This will raise a FileNotFoundError

img.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2122/1295960066.py in <cell line: 0>()
#       3 # ❌ ERROR: Wrong file name or missing file
#       4 image_path = "flow.jpg"
# ----> 5 img = Image.open(image_path)  # This will raise a FileNotFoundError
#       6
#       7 img.show()
#
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3511     if is_path(fp):
#    3512         filename = os.fspath(fp)
# -> 3513         fp = builtins.open(filename, "rb")
#    3514         exclusive_fp = True
#    3515     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'flow.jpg'

# %% [markdown]
# name error: flow.jpg change into flower.jpg

# %%
from PIL import Image

image_path = "flower.jpg"

img = Image.open(image_path)

print("Image Size:", img.size)

img.show()
# Out:
# Image Size: (4800, 4000)

# %% [markdown]
# preprocessing:

# %%
import tensorflow as tf
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing import image
import numpy as np
from PIL import Image

# ✅ Corrected file path (Make sure the file exists)
image_path = "flower.jpg"  # Provide the correct path

# ✅ Open the image properly using PIL
img = Image.open(image_path)

# ✅ Correctly resize the image (Use tuple)
img = img.resize((224, 224))

# ✅ Convert image to array before expanding dimensions
img_array = image.img_to_array(img)

# ✅ Expand dimensions correctly for model input
img_array = np.expand_dims(img_array, axis=0)

# ✅ Preprocess image for MobileNetV2
img_array = preprocess_input(img_array)

print("Preprocessed image shape:", img_array.shape)  # Expected Output: (1, 224, 224, 3)
# Out:
# Preprocessed image shape: (1, 224, 224, 3)

# %% [markdown]
# find directory files

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'flower.jpg', 'sample_data']

# %% [markdown]
# Display Image

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("flower.jpg")

plt.imshow(img)
plt.axis("off")
plt.show()
